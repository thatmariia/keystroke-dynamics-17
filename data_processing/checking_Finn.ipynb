# %%
import pandas as pd
import copy
import math
import random
from collections import defaultdict
from scipy.stats import norm

# %%
PASSWORD = "bridport20"
OWNER_NAME = "Finn Devlin"

# %%
percentile = 0.8
Z_value = norm.ppf(percentile) #inverse normal

# %%
class EntryDivider:
    """
    Separates and cleans each entry from person's dataset
    """
    
    def __init__(self, df):
        self.df = df
        self.nr_entries = self.df["entry"].max() + 1
        self.entries = self.divide_entries()
        
    def divide_entries(self):
        """
        Separates each entry from person's dataset
        """
        entries = []
        for entry_i in range(self.nr_entries):
            curr_entry = self.df[self.df["entry"] == entry_i]
            curr_entry = self._reset_time(curr_entry.sort_values(by = ["time"]).reset_index(drop = True))
            curr_entry, is_still_clean = self._remove_faulty(curr_entry)
            if (is_still_clean and self._is_correct(curr_entry)):
                entries.append(curr_entry)
            else:
                print("not clean data, entry = ", entry_i)
            
        return entries
    
    def _reset_time(self, entry):
        """
        Resets times of the entry to their relative times
        """
        start_time = entry["time"].min()
        entry["time"] -= start_time
        
        return entry
    
    def _remove_faulty(self, entry):
        """
        Checks if entry doesnt have any other pressed keys
        """
        clean_entry = copy.deepcopy(entry)
        
        for key_char in list(clean_entry["key_char"]):
            if (not key_char in PASSWORD):
                return clean_entry, False
        return clean_entry, True
    
    def _is_correct(self, entry):
        """
        Checks if entry corresponds to password
        """
        clean_entry = entry[entry["event"] == "KeyPress"]
        clean_entry = clean_entry.sort_values(by = ["time"]).reset_index(drop = True)
        entered_text = "".join(list(clean_entry["key_char"]))
        return entered_text == PASSWORD

# %%
class EventTransformer:
    """
    Detects and removes outliers from a specific person
    """
    
    def __init__(self, entries): #[DataFrame]
        self.original_entries = entries
        self.transformed_entries = self.transform_data()

    
    def transform_data(self):
        """
        Transforms entries
        """
        entries = copy.deepcopy(self.original_entries)
        
        for entry_i in range(len(entries)):
            entries[entry_i] = entries[entry_i].sort_values(by = ["key_char", "time"]).reset_index(drop = True)
            
            for event_i in range(len(entries[entry_i])):
                entries[entry_i].loc[event_i, "time"] = self._transform(entries[entry_i].loc[event_i, "time"])
                
        return entries  
    
    
    def _transform(self, time):
        return math.log(time + 0.01)

# %%
class FeatureConstructor:
    
    def __init__(self, check_entry):
        self.check_entry = check_entry
        self.presstimes = self._get_presstimes()
        self.between_keypresses = self._get_between_keypresses()
        
    
    def _get_presstimes(self):
        """
        Calculates the time each key was pressed
        """
        entry = copy.deepcopy(self.check_entry)
        entry = entry.sort_values(by = ["key_char", "time"]).reset_index(drop = True)
        
        if (len(entry) % 2 != 0):
            print("we've got uneven pressing/releasing for some reason \n")
            return
        
        elapsed_times = {}
        sorted_password = ''.join(sorted(PASSWORD))
        for i in range(len(PASSWORD)):
            elapsed_times[self._key_index(i, sorted_password[i])] = []
            
        for event_i in range(0, len(entry)-1, 2):
            elapsed_time = entry.iloc[event_i+1]["time"] - entry.iloc[event_i]["time"]
            curr_key_char = entry.iloc[event_i]["key_char"]
            elapsed_times[self._key_index((event_i+1)//2, curr_key_char)] = elapsed_time
            
        return elapsed_times
        
        
    def _get_between_keypresses(self):
        """
        Calculate times between key presses
        """
        entry = copy.deepcopy(self.check_entry)
        entry = entry[entry["event"] == "KeyPress"].sort_values(by = ["time"]).reset_index(drop = True)
        
        between_times = {}
        
        for i in range(len(PASSWORD)-1):
            between_times[self._key_index(i, PASSWORD[i] + "->" + PASSWORD[i+1])] = [] 
            
        for event_i in range(len(entry)-1):
            between_time = entry.loc[event_i+1, "time"] - entry.loc[event_i, "time"]
            curr_key_char1 = entry.iloc[event_i]["key_char"]
            curr_key_char2 = entry.iloc[event_i+1]["key_char"]
            between_times[self._key_index(event_i, curr_key_char1 + "->" + curr_key_char2)] = between_time
            
        return between_times
        
        
    def _key_index(self, index, char):
        return str(index) + ": " + char

# %%
class OwnerData:
    
    def __init__(self, distributions):
        self.distributions = distributions
        self.stats_presstimes = self._get_presstimes()
        self.stats_between_keypresses = self._get_between_keypresses()
        
    def _get_presstimes(self):
        data = self.distributions[OWNER_NAME]
        data = data.drop(data.index[0]).dropna().to_dict()
        return self._float_convert(data)
    
    def _get_between_keypresses(self):
        data = self.distributions[OWNER_NAME+".1"]
        data = data.drop(data.index[0]).dropna().to_dict()
        return self._float_convert(data)
    
    def _float_convert(self, d):
        for key, arr in d.items():
            arr_strs = list(arr[1:-1].split(", "))
            d[key] = [float(nr) for nr in arr_strs]
        return d

# %%
class ScoreCalculator:
    """
    Calculates the score!!!
    """
    
    def __init__(self, 
                 stats_presstimes, stats_between_keypresses, 
                 check_presstimes, check_between_keypresses):
        
        self.stats_presstimes = stats_presstimes
        self.stats_between_keypresses = stats_between_keypresses
        self.check_presstimes = check_presstimes
        self.check_between_keypresses = check_between_keypresses
        
        self.score = self.calculate_score()
        
    def calculate_score(self):
        return self._get_presstimes_score() + self._get_between_keypresses_score()
        
    def _get_presstimes_score(self):
        
        score = 0
        
        for key, point in self.check_presstimes.items():
            weight = self.stats_presstimes[key][0]
            mean = self.stats_presstimes[key][1]
            std = self.stats_presstimes[key][2]
            score += (weight / self._get_nr_stdevs_away(mean, std, point))
            
        return score
    
    def _get_between_keypresses_score(self):
        
        score = 0
        
        for key, point in self.check_between_keypresses.items():
            weight = self.stats_between_keypresses[key][0]
            mean = self.stats_between_keypresses[key][1]
            std = self.stats_between_keypresses[key][2]
            score += (weight / self._get_nr_stdevs_away(mean, std, point))
            
        return score
        
    def _get_nr_stdevs_away(self, mean, std, point):
        return (abs(point - mean) + 0.1) #/ std
    
    def _get_nr_stdevs_away_threshold(self, mean, std):
        return ((Z_value*std) + 0.1)

# %%
names = []
names.append("Mariia Turchina")
names.append("Sander Steeghs")
names.append("Finn Devlin")
names.append("Christian van den Berg")
names.append("Sanderijn van Loosdrecht")

def generate_entries_of(name):
    """
    Generating entries from all datasets
    """
    all_entries = []
    
    name_entries = EntryDivider(pd.read_excel(name + ".xlsx", encoding = "utf8")).entries
    name_entries = EventTransformer(name_entries).transformed_entries
            
    return name_entries

# %%
def get_random_entry():
    name = random.choice(names)
    name_entries = generate_entries_of(name)
    check_entry_i = random.randrange(0, len(name_entries))
    check_entry = name_entries[check_entry_i]
    
    print("checking entry {} of {}".format(check_entry_i, name))
    
    return [check_entry, name]

# %%
scores = defaultdict(float)
nr_attempts = defaultdict(int)
mean_scores = defaultdict(float)

nr_passes = defaultdict(int)
pass_rate = defaultdict(float)

THRESHOLD = 180

# %%
for _ in range(100):

    check_entry = get_random_entry()

    check_features = FeatureConstructor(check_entry[0])

    distributions_df = pd.read_csv("distributions.csv", encoding = "utf8", index_col = [0])
    owner_data = OwnerData(distributions_df)

    score = ScoreCalculator(owner_data.stats_presstimes, owner_data.stats_between_keypresses,
                            check_features.presstimes, check_features.between_keypresses).score
    print("score =", score, "\n")
    
    if score > THRESHOLD:
        nr_passes[check_entry[1]] += 1
    
    scores[check_entry[1]] += score
    nr_attempts[check_entry[1]] += 1
# Out:
# checking entry 37 of Christian van den Berg
# score = 140.7278379786615
#
# checking entry 240 of Finn Devlin
# score = 196.63903263377676
#
# checking entry 74 of Christian van den Berg
# score = 129.81573430580545
#
# checking entry 174 of Sanderijn van Loosdrecht
# score = 167.7557284298264
#
# checking entry 11 of Sanderijn van Loosdrecht
# score = 149.5431305392038
#
# checking entry 29 of Sander Steeghs
# score = 147.45054811312832
#
# checking entry 144 of Mariia Turchina
# score = 133.0437931295606
#
# checking entry 87 of Sanderijn van Loosdrecht
# score = 165.0401834466364
#
# checking entry 337 of Finn Devlin
# score = 171.0114753594886
#
# checking entry 208 of Finn Devlin
# score = 199.08396304488292
#
# checking entry 23 of Sanderijn van Loosdrecht
# score = 163.49393441707056
#
# checking entry 39 of Sander Steeghs
# score = 172.35129588157304
#
# checking entry 64 of Sander Steeghs
# score = 168.55861184265444
#
# checking entry 31 of Sander Steeghs
# score = 159.30147641729872
#
# checking entry 59 of Mariia Turchina
# score = 126.26344283493648
#
# checking entry 38 of Sander Steeghs
# score = 151.43624668715586
#
# checking entry 150 of Mariia Turchina
# score = 140.70528398111165
#
# checking entry 26 of Sander Steeghs
# score = 154.3919494958554
#
# checking entry 264 of Finn Devlin
# score = 187.62413219523665
#
# checking entry 19 of Sander Steeghs
# score = 172.9801331058922
#
# checking entry 68 of Christian van den Berg
# score = 128.7980841412916
#
# checking entry 23 of Sander Steeghs
# score = 164.85032052226381
#
# checking entry 4 of Mariia Turchina
# score = 125.59638737628461
#
# checking entry 110 of Mariia Turchina
# score = 141.7417440476171
#
# checking entry 22 of Finn Devlin
# score = 181.20762326478985
#
# checking entry 40 of Sanderijn van Loosdrecht
# score = 155.4850194191987
#
# checking entry 45 of Christian van den Berg
# score = 144.20134450640825
#
# checking entry 81 of Christian van den Berg
# score = 127.18055432556869
#
# checking entry 43 of Sanderijn van Loosdrecht
# score = 161.73164250752149
#
# checking entry 36 of Sander Steeghs
# score = 174.01531239685744
#
# checking entry 171 of Finn Devlin
# score = 192.53816893107717
#
# checking entry 174 of Christian van den Berg
# score = 127.27703238303576
#
# checking entry 77 of Finn Devlin
# score = 195.2917648346851
#
# checking entry 113 of Christian van den Berg
# score = 138.9037489585436
#
# checking entry 329 of Finn Devlin
# score = 198.27450661279516
#
# checking entry 14 of Sander Steeghs
# score = 167.77793355170573
#
# checking entry 117 of Christian van den Berg
# score = 132.86590161242108
#
# checking entry 102 of Christian van den Berg
# score = 128.05701685420172
#
# checking entry 173 of Sanderijn van Loosdrecht
# score = 175.16586821360625
#
# checking entry 42 of Sander Steeghs
# score = 149.30022482113532
#
# checking entry 57 of Sanderijn van Loosdrecht
# score = 139.08112432378277
#
# checking entry 73 of Sanderijn van Loosdrecht
# score = 179.0192904835584
#
# checking entry 349 of Finn Devlin
# score = 196.44409331749566
#
# checking entry 135 of Sanderijn van Loosdrecht
# score = 154.8091173771591
#
# checking entry 256 of Finn Devlin
# score = 196.9930519718916
#
# checking entry 46 of Sander Steeghs
# score = 143.2543598609866
#
# checking entry 28 of Finn Devlin
# score = 191.74582709568398
#
# checking entry 42 of Mariia Turchina
# score = 129.65319308600186
#
# checking entry 378 of Finn Devlin
# score = 169.38999437772975
#
# checking entry 0 of Christian van den Berg
# score = 119.31402860996889
#
# checking entry 63 of Christian van den Berg
# score = 142.06004259000198
#
# checking entry 130 of Mariia Turchina
# score = 150.39941867817373
#
# checking entry 61 of Sanderijn van Loosdrecht
# score = 171.72663788941657
#
# checking entry 190 of Finn Devlin
# score = 195.69672085487906
#
# checking entry 55 of Sander Steeghs
# score = 147.9514956634676
#
# checking entry 17 of Christian van den Berg
# score = 139.23428156721923
#
# checking entry 18 of Finn Devlin
# score = 159.5771340458878
#
# checking entry 125 of Christian van den Berg
# score = 143.29048524606097
#
# checking entry 31 of Sander Steeghs
# score = 159.30147641729872
#
# checking entry 141 of Sanderijn van Loosdrecht
# score = 178.99844479326194
#
# checking entry 37 of Sanderijn van Loosdrecht
# score = 157.82224184674266
#
# checking entry 7 of Sander Steeghs
# score = 169.51013545412974
#
# checking entry 50 of Mariia Turchina
# score = 120.65070628582356
#
# checking entry 141 of Mariia Turchina
# score = 139.42940045764544
#
# checking entry 21 of Mariia Turchina
# score = 129.20253680255047
#
# checking entry 60 of Sander Steeghs
# score = 146.93419870827634
#
# checking entry 63 of Christian van den Berg
# score = 142.06004259000198
#
# checking entry 10 of Christian van den Berg
# score = 132.01194108455513
#
# checking entry 43 of Sanderijn van Loosdrecht
# score = 161.73164250752149
#
# checking entry 87 of Sanderijn van Loosdrecht
# score = 165.0401834466364
#
# checking entry 262 of Finn Devlin
# score = 196.8714294809287
#
# checking entry 149 of Mariia Turchina
# score = 109.8427055297937
#
# checking entry 146 of Christian van den Berg
# score = 138.1308201428029
#
# checking entry 22 of Finn Devlin
# score = 181.20762326478985
#
# checking entry 152 of Mariia Turchina
# score = 121.37419531129657
#
# checking entry 18 of Sanderijn van Loosdrecht
# score = 140.04252010553404
#
# checking entry 125 of Christian van den Berg
# score = 143.29048524606097
#
# checking entry 142 of Christian van den Berg
# score = 142.45753614456106
#
# checking entry 8 of Sander Steeghs
# score = 133.0941503473177
#
# checking entry 330 of Finn Devlin
# score = 210.5693428573245
#
# checking entry 167 of Mariia Turchina
# score = 139.78277259091647
#
# checking entry 2 of Sanderijn van Loosdrecht
# score = 156.67923282477278
#
# checking entry 113 of Sanderijn van Loosdrecht
# score = 171.06054605986756
#
# checking entry 96 of Mariia Turchina
# score = 141.19810242565075
#
# checking entry 172 of Mariia Turchina
# score = 131.47379908454076
#
# checking entry 106 of Mariia Turchina
# score = 136.90970899455397
#
# checking entry 42 of Sander Steeghs
# score = 149.30022482113532
#
# checking entry 17 of Sanderijn van Loosdrecht
# score = 138.0619765086562
#
# checking entry 16 of Sander Steeghs
# score = 156.70626332483056
#
# checking entry 158 of Sanderijn van Loosdrecht
# score = 136.38088784367073
#
# checking entry 170 of Christian van den Berg
# score = 134.2775124512438
#
# checking entry 85 of Mariia Turchina
# score = 139.40616880826565
#
# checking entry 127 of Mariia Turchina
# score = 133.99732277916206
#
# checking entry 147 of Mariia Turchina
# score = 135.3323530106617
#
# checking entry 110 of Mariia Turchina
# score = 141.7417440476171
#
# checking entry 364 of Finn Devlin
# score = 179.9181923165254
#
# checking entry 13 of Mariia Turchina
# score = 136.1734396492422
#
# checking entry 10 of Sander Steeghs
# score = 166.16483100698412
#
# checking entry 135 of Christian van den Berg
# score = 128.51916976343688
#
# checking entry 120 of Sanderijn van Loosdrecht
# score = 182.42720254336948
#
# checking entry 274 of Finn Devlin
# score = 193.82760727588243
#
# checking entry 11 of Sander Steeghs
# score = 157.57989579842354
#
# checking entry 31 of Christian van den Berg
# score = 152.80951708183784
#
# checking entry 46 of Sander Steeghs
# score = 143.2543598609866
#
# checking entry 145 of Mariia Turchina
# score = 119.66953980002637
#
# checking entry 123 of Finn Devlin
# score = 185.33913926587928
#
# checking entry 30 of Finn Devlin
# score = 191.91453941847132
#
# checking entry 330 of Finn Devlin
# score = 210.5693428573245
#
# checking entry 364 of Finn Devlin
# score = 179.9181923165254
#
# checking entry 121 of Christian van den Berg
# score = 129.93945044301262
#
# checking entry 64 of Sander Steeghs
# score = 168.55861184265444
#
# checking entry 63 of Sanderijn van Loosdrecht
# score = 172.5680163714725
#
# checking entry 367 of Finn Devlin
# score = 166.5017957467328
#
# checking entry 20 of Sander Steeghs
# score = 171.28738244166976
#
# checking entry 139 of Sanderijn van Loosdrecht
# score = 168.32078308749914
#
# checking entry 31 of Mariia Turchina
# score = 123.58494834599742
#
# checking entry 88 of Christian van den Berg
# score = 136.0288159208826
#
# checking entry 172 of Sanderijn van Loosdrecht
# score = 166.94913380818045
#
# checking entry 138 of Sanderijn van Loosdrecht
# score = 130.15944081856566
#
# checking entry 85 of Finn Devlin
# score = 206.57238046188567
# checking entry 11 of Sander Steeghs
# score = 157.57989579842354
#
# checking entry 11 of Sanderijn van Loosdrecht
# score = 149.5431305392038
#
# checking entry 57 of Sander Steeghs
# score = 156.40197135206353
#
# checking entry 5 of Sander Steeghs
# score = 158.64235545177135
#
# checking entry 171 of Mariia Turchina
# score = 136.6287752083237
#
# checking entry 20 of Sanderijn van Loosdrecht
# score = 155.12834127887888
#
# checking entry 43 of Sander Steeghs
# score = 164.50545481726857
#
# checking entry 288 of Finn Devlin
# score = 200.612661083908
#
# checking entry 14 of Sanderijn van Loosdrecht
# score = 159.85863948513224
#
# checking entry 53 of Sander Steeghs
# score = 152.7185756394741
#
# checking entry 304 of Finn Devlin
# score = 182.61926926614177
#
# checking entry 97 of Christian van den Berg
# score = 134.28194850326514
#
# checking entry 56 of Mariia Turchina
# score = 134.56004690210523
#
# checking entry 47 of Sander Steeghs
# score = 163.9488538316611
#
# checking entry 63 of Sanderijn van Loosdrecht
# score = 172.5680163714725
#
# checking entry 113 of Christian van den Berg
# score = 138.9037489585436
#
# checking entry 131 of Mariia Turchina
# score = 146.96643839943164
#
# checking entry 36 of Sander Steeghs
# score = 174.01531239685744
#
# checking entry 43 of Sander Steeghs
# score = 164.50545481726857
#
# checking entry 0 of Christian van den Berg
# score = 119.31402860996889
#
# checking entry 70 of Mariia Turchina
# score = 130.92815220597345
#
# checking entry 146 of Christian van den Berg
# score = 138.1308201428029
#
# checking entry 60 of Sander Steeghs
# score = 146.93419870827634
#
# checking entry 233 of Finn Devlin
# score = 196.21453940919451
#
# checking entry 55 of Mariia Turchina
# score = 132.6813923402223
#
# checking entry 385 of Finn Devlin
# score = 180.21260648094216
#
# checking entry 171 of Sanderijn van Loosdrecht
# score = 160.95699364894625
#
# checking entry 154 of Christian van den Berg
# score = 131.51639864748665
#
# checking entry 21 of Finn Devlin
# score = 188.2589908752923
#
# checking entry 145 of Finn Devlin
# score = 199.28436123149874
#
# checking entry 46 of Sander Steeghs
# score = 143.2543598609866
#
# checking entry 39 of Sander Steeghs
# score = 172.35129588157304
#
# checking entry 36 of Sander Steeghs
# score = 174.01531239685744
#
# checking entry 98 of Sanderijn van Loosdrecht
# score = 169.84605517888596
#
# checking entry 365 of Finn Devlin
# score = 195.21068073305435
#
# checking entry 66 of Sanderijn van Loosdrecht
# score = 166.3418216715988
#
# checking entry 25 of Sanderijn van Loosdrecht
# score = 132.40975735878533
#
# checking entry 20 of Christian van den Berg
# score = 137.39501443598203
#
# checking entry 172 of Christian van den Berg
# score = 130.86759050503986
#
# checking entry 38 of Christian van den Berg
# score = 130.9375002982168
#
# checking entry 56 of Sander Steeghs
# score = 160.4322689918829
#
# checking entry 32 of Sander Steeghs
# score = 171.02215827802854
#
# checking entry 164 of Mariia Turchina
# score = 134.61604881763537
#
# checking entry 64 of Sanderijn van Loosdrecht
# score = 177.80673090144404
#
# checking entry 12 of Finn Devlin
# score = 193.26137244261835
#
# checking entry 24 of Sander Steeghs
# score = 153.33226829733167
#
# checking entry 105 of Sanderijn van Loosdrecht
# score = 171.54960095230084
#
# checking entry 99 of Christian van den Berg
# score = 112.85861716100044
#
# checking entry 154 of Finn Devlin
# score = 209.71038632380072
#
# checking entry 59 of Sander Steeghs
# score = 147.22580960022202
#
# checking entry 77 of Sanderijn van Loosdrecht
# score = 184.95790253886238
#
# checking entry 56 of Mariia Turchina
# score = 134.56004690210523
#
# checking entry 123 of Sanderijn van Loosdrecht
# score = 126.76522343501628
#
# checking entry 37 of Sander Steeghs
# score = 167.16586764879509
#
# checking entry 86 of Mariia Turchina
# score = 145.71882672878522
#
# checking entry 39 of Finn Devlin
# score = 198.0481480691239
#
# checking entry 17 of Christian van den Berg
# score = 139.23428156721923
#
# checking entry 60 of Mariia Turchina
# score = 137.20566205725305
#
# checking entry 112 of Mariia Turchina
# score = 133.12155209029243
#
# checking entry 66 of Christian van den Berg
# score = 130.9645934288024
#
# checking entry 71 of Finn Devlin
# score = 181.96282000791177
#
# checking entry 5 of Christian van den Berg
# score = 124.50099086382423
#
# checking entry 66 of Mariia Turchina
# score = 138.64893323065985
#
# checking entry 364 of Finn Devlin
# score = 179.9181923165254
#
# checking entry 68 of Sander Steeghs
# score = 136.93632490651638
#
# checking entry 32 of Sanderijn van Loosdrecht
# score = 144.0120744153715
#
# checking entry 380 of Finn Devlin
# score = 183.4741741365015
#
# checking entry 43 of Sander Steeghs
# score = 164.50545481726857
#
# checking entry 173 of Sanderijn van Loosdrecht
# score = 175.16586821360625
#
# checking entry 275 of Finn Devlin
# score = 189.9039374508489
#
# checking entry 12 of Mariia Turchina
# score = 129.98441683642267
#
# checking entry 13 of Sander Steeghs
# score = 165.85467525537211
#
# checking entry 105 of Finn Devlin
# score = 209.32617160426324
#
# checking entry 46 of Sander Steeghs
# score = 143.2543598609866
#
# checking entry 42 of Sander Steeghs
# score = 149.30022482113532
#
# checking entry 15 of Sanderijn van Loosdrecht
# score = 155.0688316260755
#
# checking entry 155 of Christian van den Berg
# score = 134.8816298409048
#
# checking entry 165 of Sanderijn van Loosdrecht
# score = 109.59033536955866
#
# checking entry 163 of Christian van den Berg
# score = 112.56849865607742
#
# checking entry 144 of Mariia Turchina
# score = 133.0437931295606
#
# checking entry 246 of Finn Devlin
# score = 187.48479822816358
#
# checking entry 169 of Christian van den Berg
# score = 114.9094594000111
#
# checking entry 44 of Sander Steeghs
# score = 156.14657557696262
#
# checking entry 140 of Sanderijn van Loosdrecht
# score = 172.5289187306984
#
# checking entry 172 of Christian van den Berg
# score = 130.86759050503986
#
# checking entry 173 of Mariia Turchina
# score = 138.02580943631796
#
# checking entry 166 of Finn Devlin
# score = 140.8532811311582
#
# checking entry 157 of Christian van den Berg
# score = 104.10709768097286
#
# checking entry 97 of Christian van den Berg
# score = 134.28194850326514
#
# checking entry 21 of Sander Steeghs
# score = 169.74280992951435
#
# checking entry 3 of Sander Steeghs
# score = 166.3900509370425
#
# checking entry 158 of Sanderijn van Loosdrecht
# score = 136.38088784367073
#
# checking entry 36 of Sander Steeghs
# score = 174.01531239685744
#
# checking entry 85 of Christian van den Berg
# score = 127.14529114172471
#
# checking entry 133 of Mariia Turchina
# score = 147.2125871242862
#
# checking entry 140 of Sanderijn van Loosdrecht
# score = 172.5289187306984
#
# checking entry 151 of Sanderijn van Loosdrecht
# score = 174.1981606769748
#
# checking entry 72 of Sanderijn van Loosdrecht
# score = 182.94443946368744
#
# checking entry 59 of Christian van den Berg
# score = 145.19678764565393
#
# checking entry 111 of Mariia Turchina
# score = 138.20858628271029
#
# checking entry 36 of Sander Steeghs
# score = 174.01531239685744
#
# checking entry 54 of Mariia Turchina
# score = 126.12434307408563
#
# checking entry 5 of Sander Steeghs
# score = 158.64235545177135
#
# checking entry 345 of Finn Devlin
# score = 201.19150169995774
#
# checking entry 55 of Christian van den Berg
# score = 124.6438346796941
#
# checking entry 232 of Finn Devlin
# score = 182.79619808562097
#
# checking entry 168 of Christian van den Berg
# score = 118.62019371518477
#
# checking entry 57 of Sander Steeghs
# score = 156.40197135206353
#
# checking entry 63 of Sander Steeghs
# score = 139.75535522996483
#
# checking entry 63 of Sanderijn van Loosdrecht
# score = 172.5680163714725
#
# checking entry 41 of Sanderijn van Loosdrecht
# score = 162.54403819813078
#
# checking entry 6 of Sander Steeghs
# score = 169.4437358490705
#
# checking entry 30 of Finn Devlin
# score = 191.91453941847132
#
# checking entry 25 of Sander Steeghs
# score = 155.63707290536934
#
# checking entry 103 of Sanderijn van Loosdrecht
# score = 146.82964186971367
#
# checking entry 179 of Finn Devlin
# score = 203.003879634758
#
# checking entry 60 of Sanderijn van Loosdrecht
# score = 164.47246136666462
#
# checking entry 57 of Sander Steeghs
# score = 156.40197135206353
#
# checking entry 47 of Sander Steeghs
# score = 163.9488538316611
#
# checking entry 221 of Finn Devlin
# score = 193.998003421889
#
# checking entry 43 of Sander Steeghs
# score = 164.50545481726857
# checking entry 380 of Finn Devlin
# score = 183.4741741365015
#
# checking entry 170 of Mariia Turchina
# score = 133.85283765005607
#
# checking entry 54 of Sanderijn van Loosdrecht
# score = 166.43540092128163
#
# checking entry 38 of Christian van den Berg
# score = 130.9375002982168
#
# checking entry 76 of Sanderijn van Loosdrecht
# score = 175.1003596555034
#
# checking entry 133 of Mariia Turchina
# score = 147.2125871242862
#
# checking entry 27 of Sanderijn van Loosdrecht
# score = 152.69951703954132
#
# checking entry 124 of Sanderijn van Loosdrecht
# score = 163.10812967982568
#
# checking entry 341 of Finn Devlin
# score = 194.25687254684175
#
# checking entry 25 of Christian van den Berg
# score = 118.30145999528939
#
# checking entry 77 of Christian van den Berg
# score = 121.4024674736698
#
# checking entry 147 of Christian van den Berg
# score = 133.14978629622124
#
# checking entry 150 of Christian van den Berg
# score = 138.29607492142975
#
# checking entry 23 of Mariia Turchina
# score = 135.97639200805622
#
# checking entry 367 of Finn Devlin
# score = 166.5017957467328
#
# checking entry 25 of Sander Steeghs
# score = 155.63707290536934
#
# checking entry 12 of Christian van den Berg
# score = 141.32606161574185
#
# checking entry 163 of Sanderijn van Loosdrecht
# score = 145.64921504739857
#
# checking entry 157 of Mariia Turchina
# score = 137.06270290536554
#
# checking entry 104 of Finn Devlin
# score = 203.17709888474593
#
# checking entry 50 of Sander Steeghs
# score = 171.71459879617066
#
# checking entry 68 of Mariia Turchina
# score = 137.56333821947916
#
# checking entry 313 of Finn Devlin
# score = 205.2997073936772
#
# checking entry 32 of Sander Steeghs
# score = 171.02215827802854
#
# checking entry 56 of Sander Steeghs
# score = 160.4322689918829
#
# checking entry 85 of Christian van den Berg
# score = 127.14529114172471
#
# checking entry 159 of Finn Devlin
# score = 215.96120741662315
#
# checking entry 55 of Christian van den Berg
# score = 124.6438346796941
#
# checking entry 254 of Finn Devlin
# score = 187.14855192072102
#
# checking entry 30 of Sanderijn van Loosdrecht
# score = 149.73298601801972
#
# checking entry 33 of Sander Steeghs
# score = 169.5307955047316
#
# checking entry 135 of Sanderijn van Loosdrecht
# score = 154.8091173771591
#
# checking entry 62 of Sanderijn van Loosdrecht
# score = 180.24728611346305
#
# checking entry 0 of Sander Steeghs
# score = 167.1346994664611
#
# checking entry 159 of Sanderijn van Loosdrecht
# score = 127.47202893359547
#
# checking entry 131 of Christian van den Berg
# score = 128.27575770794007
#
# checking entry 171 of Christian van den Berg
# score = 123.60465937726119
#
# checking entry 163 of Finn Devlin
# score = 209.32982008278935
#
# checking entry 22 of Christian van den Berg
# score = 132.49763862230242
#
# checking entry 264 of Finn Devlin
# score = 187.62413219523665
#
# checking entry 169 of Mariia Turchina
# score = 132.60120621766782
#
# checking entry 46 of Sander Steeghs
# score = 143.2543598609866
#
# checking entry 9 of Sander Steeghs
# score = 156.10452432278197
#
# checking entry 132 of Sanderijn van Loosdrecht
# score = 181.0932151389069
#
# checking entry 360 of Finn Devlin
# score = 190.4013005564252
#
# checking entry 87 of Mariia Turchina
# score = 128.55234599359164
#
# checking entry 118 of Sanderijn van Loosdrecht
# score = 172.52458946359462
#
# checking entry 31 of Mariia Turchina
# score = 123.58494834599742
#
# checking entry 85 of Mariia Turchina
# score = 139.40616880826565
#
# checking entry 160 of Christian van den Berg
# score = 126.10951042455044
#
# checking entry 162 of Christian van den Berg
# score = 133.56892173725984
#
# checking entry 10 of Sander Steeghs
# score = 166.16483100698412
#
# checking entry 3 of Sander Steeghs
# score = 166.3900509370425
#
# checking entry 106 of Mariia Turchina
# score = 136.90970899455397
#
# checking entry 9 of Christian van den Berg
# score = 132.66879366934938
#
# checking entry 207 of Finn Devlin
# score = 200.68909212012144
#
# checking entry 76 of Mariia Turchina
# score = 133.5963976826418
#
# checking entry 57 of Sander Steeghs
# score = 156.40197135206353
#
# checking entry 21 of Christian van den Berg
# score = 142.4895594599929
#
# checking entry 169 of Sanderijn van Loosdrecht
# score = 150.14019103102441
#
# checking entry 150 of Sanderijn van Loosdrecht
# score = 175.40257328979192
#
# checking entry 123 of Christian van den Berg
# score = 117.77725696146109
#
# checking entry 41 of Mariia Turchina
# score = 114.9172349407603
#
# checking entry 102 of Mariia Turchina
# score = 154.64665884959314
#
# checking entry 88 of Sanderijn van Loosdrecht
# score = 163.46328535060377
#
# checking entry 68 of Sander Steeghs
# score = 136.93632490651638
#
# checking entry 1 of Sanderijn van Loosdrecht
# score = 151.02246265445294
#
# checking entry 103 of Mariia Turchina
# score = 148.58126984967984
#
# checking entry 6 of Christian van den Berg
# score = 144.18163379045188
#
# checking entry 124 of Mariia Turchina
# score = 138.36871945888836
#
# checking entry 65 of Sander Steeghs
# score = 168.67672879356985
#
# checking entry 152 of Mariia Turchina
# score = 121.37419531129657
#
# checking entry 299 of Finn Devlin
# score = 209.95568280839885
#
# checking entry 107 of Mariia Turchina
# score = 130.16752264218167
#
# checking entry 88 of Finn Devlin
# score = 196.67147747389288
#
# checking entry 135 of Mariia Turchina
# score = 151.2547240979385
#
# checking entry 193 of Finn Devlin
# score = 206.3799648375189
#
# checking entry 53 of Sander Steeghs
# score = 152.7185756394741
#
# checking entry 119 of Christian van den Berg
# score = 112.1248220170134
#
# checking entry 60 of Sander Steeghs
# score = 146.93419870827634
#
# checking entry 353 of Finn Devlin
# score = 188.39948698470502
#
# checking entry 62 of Mariia Turchina
# score = 140.52629234950157
#
# checking entry 24 of Mariia Turchina
# score = 139.42517488821198
#
# checking entry 202 of Finn Devlin
# score = 188.05857008808727
#
# checking entry 276 of Finn Devlin
# score = 208.07116994525626
#
# checking entry 62 of Sander Steeghs
# score = 160.47597898871615
#
# checking entry 82 of Christian van den Berg
# score = 114.39885423134076
#
# checking entry 120 of Mariia Turchina
# score = 139.9699631643681
#
# checking entry 59 of Sander Steeghs
# score = 147.22580960022202
#
# checking entry 67 of Sanderijn van Loosdrecht
# score = 143.93709524539352
#
# checking entry 142 of Christian van den Berg
# score = 142.45753614456106
#
# checking entry 117 of Christian van den Berg
# score = 132.86590161242108
#
# checking entry 267 of Finn Devlin
# score = 204.53162600034574
#
# checking entry 115 of Mariia Turchina
# score = 138.86047158352144
#
# checking entry 316 of Finn Devlin
# score = 195.93765083350803
#
# checking entry 360 of Finn Devlin
# score = 190.4013005564252
#
# checking entry 103 of Mariia Turchina
# score = 148.58126984967984
#
# checking entry 226 of Finn Devlin
# score = 202.37230889720306
#
# checking entry 144 of Mariia Turchina
# score = 133.0437931295606
#
# checking entry 35 of Sanderijn van Loosdrecht
# score = 169.172307364517
#
# checking entry 17 of Mariia Turchina
# score = 130.39824910221162
#
# checking entry 383 of Finn Devlin
# score = 199.31900069204642
#
# checking entry 232 of Finn Devlin
# score = 182.79619808562097
#
# checking entry 153 of Sanderijn van Loosdrecht
# score = 162.60746981480366
#
# checking entry 3 of Sander Steeghs
# score = 166.3900509370425
#
# checking entry 288 of Finn Devlin
# score = 200.612661083908
#
# checking entry 144 of Christian van den Berg
# score = 130.03600944465185
#
# checking entry 135 of Sanderijn van Loosdrecht
# score = 154.8091173771591
#
# checking entry 28 of Sander Steeghs
# score = 158.2544438526162
#
# checking entry 32 of Sander Steeghs
# score = 171.02215827802854
#
# checking entry 247 of Finn Devlin
# score = 201.8534774512011
#
# checking entry 170 of Finn Devlin
# score = 192.4484524823656
#
# checking entry 6 of Christian van den Berg
# score = 144.18163379045188
#
# checking entry 132 of Christian van den Berg
# score = 114.66812616845611
#
# checking entry 171 of Mariia Turchina
# score = 136.6287752083237
#
# checking entry 15 of Christian van den Berg
# score = 111.29009388561798
#
# checking entry 110 of Sanderijn van Loosdrecht
# score = 176.13210433973697
#
# checking entry 73 of Mariia Turchina
# score = 121.96270640887217
#
# checking entry 33 of Mariia Turchina
# score = 128.18950415315135
#
# checking entry 56 of Mariia Turchina
# score = 134.56004690210523
#
# checking entry 124 of Finn Devlin
# score = 200.18174899040878
# checking entry 21 of Sander Steeghs
# score = 169.74280992951435
#
# checking entry 25 of Sander Steeghs
# score = 155.63707290536934
#
# checking entry 64 of Mariia Turchina
# score = 123.75249723630893
#
# checking entry 51 of Mariia Turchina
# score = 129.05308936598212
#
# checking entry 67 of Mariia Turchina
# score = 143.44090016148863
#
# checking entry 155 of Sanderijn van Loosdrecht
# score = 155.17478934358718
#
# checking entry 146 of Christian van den Berg
# score = 138.1308201428029
#
# checking entry 88 of Finn Devlin
# score = 196.67147747389288
#
# checking entry 6 of Sander Steeghs
# score = 169.4437358490705
#
# checking entry 77 of Christian van den Berg
# score = 121.4024674736698
#
# checking entry 82 of Sanderijn van Loosdrecht
# score = 175.74895992424752
#
# checking entry 378 of Finn Devlin
# score = 169.38999437772975
#
# checking entry 250 of Finn Devlin
# score = 197.58070727050398
#
# checking entry 16 of Finn Devlin
# score = 150.3318206666987
#
# checking entry 37 of Sander Steeghs
# score = 167.16586764879509
#
# checking entry 57 of Finn Devlin
# score = 203.31835067099126
#
# checking entry 24 of Sander Steeghs
# score = 153.33226829733167
#
# checking entry 207 of Finn Devlin
# score = 200.68909212012144
#
# checking entry 51 of Finn Devlin
# score = 208.40489333359395
#
# checking entry 3 of Christian van den Berg
# score = 134.20991498712146
#
# checking entry 171 of Mariia Turchina
# score = 136.6287752083237
#
# checking entry 7 of Sander Steeghs
# score = 169.51013545412974
#
# checking entry 110 of Mariia Turchina
# score = 141.7417440476171
#
# checking entry 80 of Finn Devlin
# score = 206.92141052993827
#
# checking entry 25 of Sanderijn van Loosdrecht
# score = 132.40975735878533
#
# checking entry 122 of Sanderijn van Loosdrecht
# score = 158.110388027311
#
# checking entry 37 of Mariia Turchina
# score = 130.53205979198503
#
# checking entry 154 of Finn Devlin
# score = 209.71038632380072
#
# checking entry 60 of Sander Steeghs
# score = 146.93419870827634
#
# checking entry 9 of Sander Steeghs
# score = 156.10452432278197
#
# checking entry 5 of Mariia Turchina
# score = 127.00808819017547
#
# checking entry 132 of Christian van den Berg
# score = 114.66812616845611
#
# checking entry 5 of Christian van den Berg
# score = 124.50099086382423
#
# checking entry 99 of Sanderijn van Loosdrecht
# score = 184.81640803405912
#
# checking entry 172 of Sanderijn van Loosdrecht
# score = 166.94913380818045
#
# checking entry 47 of Sanderijn van Loosdrecht
# score = 154.3747621273039
#
# checking entry 39 of Sander Steeghs
# score = 172.35129588157304
#
# checking entry 169 of Mariia Turchina
# score = 132.60120621766782
#
# checking entry 27 of Sander Steeghs
# score = 170.4217636814024
#
# checking entry 251 of Finn Devlin
# score = 212.52500401588583
#
# checking entry 114 of Sanderijn van Loosdrecht
# score = 176.54206233815773
#
# checking entry 332 of Finn Devlin
# score = 209.70403599702001
#
# checking entry 305 of Finn Devlin
# score = 193.67993258564036
#
# checking entry 167 of Mariia Turchina
# score = 139.78277259091647
#
# checking entry 27 of Sanderijn van Loosdrecht
# score = 152.69951703954132
#
# checking entry 51 of Mariia Turchina
# score = 129.05308936598212
#
# checking entry 26 of Finn Devlin
# score = 200.0637799883794
#
# checking entry 143 of Sanderijn van Loosdrecht
# score = 170.46771698739383
#
# checking entry 75 of Sanderijn van Loosdrecht
# score = 162.08159773317658
#
# checking entry 35 of Sanderijn van Loosdrecht
# score = 169.172307364517
#
# checking entry 65 of Mariia Turchina
# score = 115.23339147724323
#
# checking entry 100 of Mariia Turchina
# score = 132.44897558862732
#
# checking entry 116 of Mariia Turchina
# score = 138.83387071628894
#
# checking entry 97 of Mariia Turchina
# score = 144.5613003510266
#
# checking entry 68 of Christian van den Berg
# score = 128.7980841412916
#
# checking entry 131 of Mariia Turchina
# score = 146.96643839943164
#
# checking entry 202 of Finn Devlin
# score = 188.05857008808727
#
# checking entry 348 of Finn Devlin
# score = 193.77370158233302
#
# checking entry 125 of Finn Devlin
# score = 204.78883353653123
#
# checking entry 163 of Finn Devlin
# score = 209.32982008278935
#
# checking entry 119 of Sanderijn van Loosdrecht
# score = 140.47464543823278
#
# checking entry 2 of Finn Devlin
# score = 189.67250351187266
#
# checking entry 35 of Sander Steeghs
# score = 162.82459050569943
#
# checking entry 170 of Sanderijn van Loosdrecht
# score = 132.4734130591798
#
# checking entry 129 of Sanderijn van Loosdrecht
# score = 162.02877944838764
#
# checking entry 170 of Mariia Turchina
# score = 133.85283765005607
#
# checking entry 15 of Christian van den Berg
# score = 111.29009388561798
#
# checking entry 253 of Finn Devlin
# score = 187.38497545244417
#
# checking entry 90 of Sanderijn van Loosdrecht
# score = 134.75652334600719
#
# checking entry 81 of Sanderijn van Loosdrecht
# score = 161.42423021811032
#
# checking entry 140 of Mariia Turchina
# score = 130.57781719475304
#
# checking entry 54 of Mariia Turchina
# score = 126.12434307408563
#
# checking entry 31 of Mariia Turchina
# score = 123.58494834599742
#
# checking entry 90 of Christian van den Berg
# score = 121.89952657987106
#
# checking entry 179 of Finn Devlin
# score = 203.003879634758
#
# checking entry 45 of Mariia Turchina
# score = 128.70238711763113
#
# checking entry 165 of Christian van den Berg
# score = 110.71559397742382
#
# checking entry 319 of Finn Devlin
# score = 194.4919149768558
#
# checking entry 1 of Sanderijn van Loosdrecht
# score = 151.02246265445294
#
# checking entry 130 of Sanderijn van Loosdrecht
# score = 178.75489079187068
#
# checking entry 46 of Finn Devlin
# score = 209.92814866338404
#
# checking entry 168 of Sanderijn van Loosdrecht
# score = 165.12051289540977
#
# checking entry 150 of Sanderijn van Loosdrecht
# score = 175.40257328979192
#
# checking entry 183 of Finn Devlin
# score = 208.3886958149825
#
# checking entry 8 of Mariia Turchina
# score = 126.56633214755385
#
# checking entry 48 of Christian van den Berg
# score = 143.45919210354256
#
# checking entry 33 of Sanderijn van Loosdrecht
# score = 162.13084477447404
#
# checking entry 128 of Sanderijn van Loosdrecht
# score = 149.01177477841148
#
# checking entry 296 of Finn Devlin
# score = 194.4425075771453
#
# checking entry 12 of Sanderijn van Loosdrecht
# score = 167.83128663414354
#
# checking entry 34 of Sander Steeghs
# score = 155.0852515867644
#
# checking entry 10 of Sanderijn van Loosdrecht
# score = 169.74606918600202
#
# checking entry 37 of Mariia Turchina
# score = 130.53205979198503
#
# checking entry 21 of Sander Steeghs
# score = 169.74280992951435
#
# checking entry 104 of Christian van den Berg
# score = 139.90427658087214
#
# checking entry 75 of Sanderijn van Loosdrecht
# score = 162.08159773317658
#
# checking entry 6 of Christian van den Berg
# score = 144.18163379045188
#
# checking entry 55 of Sander Steeghs
# score = 147.9514956634676
#
# checking entry 52 of Sander Steeghs
# score = 146.65133437300187
#
# checking entry 75 of Christian van den Berg
# score = 115.05051076480723
#
# checking entry 12 of Sanderijn van Loosdrecht
# score = 167.83128663414354
#
# checking entry 63 of Sander Steeghs
# score = 139.75535522996483
#
# checking entry 54 of Mariia Turchina
# score = 126.12434307408563
#
# checking entry 78 of Christian van den Berg
# score = 132.91702325894258
#
# checking entry 15 of Christian van den Berg
# score = 111.29009388561798
#
# checking entry 186 of Finn Devlin
# score = 178.52537956856867
#
# checking entry 120 of Christian van den Berg
# score = 127.51070718439331
#
# checking entry 52 of Sanderijn van Loosdrecht
# score = 170.86360302132167
#
# checking entry 6 of Sanderijn van Loosdrecht
# score = 123.27240373453917
#
# checking entry 134 of Sanderijn van Loosdrecht
# score = 165.05460533667826
#
# checking entry 168 of Christian van den Berg
# score = 118.62019371518477
#
# checking entry 122 of Finn Devlin
# score = 191.485825983749
#
# checking entry 86 of Mariia Turchina
# score = 145.71882672878522
#
# checking entry 186 of Finn Devlin
# score = 178.52537956856867
#
# checking entry 34 of Sanderijn van Loosdrecht
# score = 154.88452172820297
#
# checking entry 196 of Finn Devlin
# score = 200.0058099704907
#
# checking entry 163 of Mariia Turchina
# score = 150.11458291558114
#
# checking entry 125 of Mariia Turchina
# score = 136.98426759239345
#
# checking entry 24 of Sander Steeghs
# score = 153.33226829733167
#
# checking entry 13 of Christian van den Berg
# score = 122.03618711694247
# checking entry 11 of Sander Steeghs
# score = 157.57989579842354
#
# checking entry 211 of Finn Devlin
# score = 185.0164704560795
#
# checking entry 62 of Sander Steeghs
# score = 160.47597898871615
#
# checking entry 45 of Mariia Turchina
# score = 128.70238711763113
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-f15241959d98> in <module>
#       1 for _ in range(500):
#       2
# ----> 3     check_entry = get_random_entry()
#       4
#       5     check_features = FeatureConstructor(check_entry[0])
#
# <ipython-input-9-a0efb84afdd8> in get_random_entry()
#       1 def get_random_entry():
#       2     name = random.choice(names)
# ----> 3     name_entries = generate_entries_of(name)
#       4     check_entry_i = random.randrange(0, len(name_entries))
#       5     check_entry = name_entries[check_entry_i]
#
# <ipython-input-8-1bbf5990de11> in generate_entries_of(name)
#      13
#      14     name_entries = EntryDivider(pd.read_excel(name + ".xlsx", encoding = "utf8")).entries
# ---> 15     name_entries = EventTransformer(name_entries).transformed_entries
#      16
#      17     return name_entries
#
# <ipython-input-4-2415d0760935> in __init__(self, entries)
#       6     def __init__(self, entries): #[DataFrame]
#       7         self.original_entries = entries
# ----> 8         self.transformed_entries = self.transform_data()
#       9
#      10
#
# <ipython-input-4-2415d0760935> in transform_data(self)
#      19
#      20             for event_i in range(len(entries[entry_i])):
# ---> 21                 entries[entry_i].loc[event_i, "time"] = self._transform(entries[entry_i].loc[event_i, "time"])
#      22
#      23         return entries
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     188             key = com.apply_if_callable(key, self.obj)
#     189         indexer = self._get_setitem_indexer(key)
# --> 190         self._setitem_with_indexer(indexer, value)
#     191
#     192     def _validate_key(self, key, axis):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer(self, indexer, value)
#     618                 # scalar
#     619                 for item in labels:
# --> 620                     setter(item, value)
#     621
#     622         else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in setter(item, v)
#     541
#     542                 # reset the sliced object if unique
# --> 543                 self.obj[item] = s
#     544
#     545             def can_do_equal_len():
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3368         else:
#    3369             # set column
# -> 3370             self._set_item(key, value)
#    3371
#    3372     def _setitem_slice(self, key, value):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3444         self._ensure_valid_index(value)
#    3445         value = self._sanitize_column(key, value)
# -> 3446         NDFrame._set_item(self, key, value)
#    3447
#    3448         # check if we are modifying a copy
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _set_item(self, key, value)
#    3170
#    3171     def _set_item(self, key, value):
# -> 3172         self._data.set(key, value)
#    3173         self._clear_item_cache()
#    3174
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in set(self, item, value)
#    1061
#    1062         blknos = self._blknos[loc]
# -> 1063         blklocs = self._blklocs[loc].copy()
#    1064
#    1065         unfit_mgr_locs = []
#
# KeyboardInterrupt:

# %%
for i in names:
    mean_scores[i] = (scores[i]/nr_attempts[i])
    pass_rate[i] = (nr_passes[i]/nr_attempts[i])


print(nr_attempts)
print(nr_passes)

print(mean_scores)
print(pass_rate)
# Out:
# defaultdict(<class 'int'>, {'Christian van den Berg': 88, 'Finn Devlin': 103, 'Sanderijn van Loosdrecht': 101, 'Sander Steeghs': 98, 'Mariia Turchina': 96})
# defaultdict(<class 'int'>, {'Finn Devlin': 90, 'Sanderijn van Loosdrecht': 6, 'Mariia Turchina': 0, 'Sander Steeghs': 0, 'Christian van den Berg': 0})
# defaultdict(<class 'float'>, {'Mariia Turchina': 134.40006932419806, 'Sander Steeghs': 159.2318875307986, 'Finn Devlin': 193.31704290182878, 'Christian van den Berg': 129.73140762416097, 'Sanderijn van Loosdrecht': 160.1379268563778})
# defaultdict(<class 'float'>, {'Mariia Turchina': 0.0, 'Sander Steeghs': 0.0, 'Finn Devlin': 0.8737864077669902, 'Christian van den Berg': 0.0, 'Sanderijn van Loosdrecht': 0.0594059405940594})

# %%
#1000 tests for Finn
#threshold = 180,  TESTS_WEIGHT = 0.8, STD_WEIGHT = 1, distance_weight = 0.1, dividing through by std
'''average score after 1000:
Mariia = 185
Finn = 130
Sander = 123
Sanderijn = 130
Christian = 150

Pass rate:
Mariia = 0.87
Finn = 0
Sander = 0 
Sanderijn = 0
Christian = 0.03
'''

# %%
#1000 tests
#threshold = 170,  TESTS_WEIGHT = 0.8, STD_WEIGHT = 1, distance_weight = 0.1, dividing through by std
'''average score after 1000:
Mariia = 185
Finn = 130
Sander = 123
Sanderijn = 130
Christian = 150

Pass rate:
Mariia = 0.87
Finn = 0
Sander = 0 
Sanderijn = 0
Christian = 0.03
'''

# %%
#Threshold = 100, TESTS_WEIGHT = 0.8, STD_WEIGHT = 1
'''average score:
Mariia = 135, 144
Finn = 57, 68
Sander = 105, 49, 
Sanderijn = 68, 34
Christian = 61, 52

Pass rate:
Mariia = 0.37
Finn = 0.1
Sander = 0.13 
Sanderijn = 0.07
Christian = 0.1
'''

# %%
#threshold = 6,  TESTS_WEIGHT = 0.8, STD_WEIGHT = 1, distance_weight = 0.1
'''average score:
Mariia = 6.4
Finn = 4.3
Sander = 5.1 
Sanderijn = 4.6
Christian = 4.6

Pass rate:
Mariia = 0.70
Finn = 0.24
Sander = 0 
Sanderijn = 0.06
Christian = 0
'''
